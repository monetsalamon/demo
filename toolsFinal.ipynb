# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Amanda Monet Salamon </b>
#
# Data Analyst

# %% [markdown]
# <i> I am interested in Data Science because it can change the world. It can give insight into how people live and how there lives can be improved. </i>

# %% [markdown]
# <h3>This code does basic math</h3>

# %%
x=7
x+5
# Out:
# 12

# %% [markdown]
# <hr>
#
# 1. one
# 2. two
# 3. three
# 4. four
# 5. five
#
# <hr>
#
# <blockquote> This is a house </blockquote>
# <hr>
#
# <img src="https://th.bing.com/th/id/OIP.NHSJczJkZbt4zupW-H57swHaE8?w=274&h=183&c=7&r=0&o=5&dpr=2&pid=1.7">
